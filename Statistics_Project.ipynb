# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import scipy.stats

# %%
df = pd.read_excel("C:/Users/Roshith/Downloads/aspiring_minds_employability_outcomes_2015.xlsx")

# %%
df
# Out:
#      Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0         train  203097   420000 2012-06-01              present
# 1         train  579905   500000 2013-09-01              present
# 2         train  810601   325000 2014-06-01              present
# 3         train  267447  1100000 2011-07-01              present
# 4         train  343523   200000 2014-03-01  2015-03-01 00:00:00
# ...         ...     ...      ...        ...                  ...
# 3993      train   47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994      train  752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995      train  355888   320000 2013-07-01              present
# 3996      train  947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997      train  324966   400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 0         senior quality engineer         Bangalore      f 1990-02-19
# ...

# %%
df=df.drop(['Unnamed: 0'], axis = 1)

# %%
df
# Out:
#           ID   Salary        DOJ                  DOL  \
# 0     203097   420000 2012-06-01              present
# 1     579905   500000 2013-09-01              present
# 2     810601   325000 2014-06-01              present
# 3     267447  1100000 2011-07-01              present
# 4     343523   200000 2014-03-01  2015-03-01 00:00:00
# ...      ...      ...        ...                  ...
# 3993   47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994  752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995  355888   320000 2013-07-01              present
# 3996  947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997  324966   400000 2013-02-01              present
#
#                       Designation           JobCity Gender        DOB  \
# 0         senior quality engineer         Bangalore      f 1990-02-19
# 1               assistant manager            Indore      m 1989-10-04
# 2                systems engineer           Chennai      f 1992-08-03
# ...

# %%
df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   int64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   datetime64[ns]
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
df['Salary']
# Out:
# 0        420000
# 1        500000
# 2        325000
# 3       1100000
# 4        200000
#          ...
# 3993     280000
# 3994     100000
# 3995     320000
# 3996     200000
# 3997     400000
# Name: Salary, Length: 3998, dtype: int64

# %%
df['Salary'].unique
# Out:
# <bound method Series.unique of 0        420000
# 1        500000
# 2        325000
# 3       1100000
# 4        200000
#          ...
# 3993     280000
# 3994     100000
# 3995     320000
# 3996     200000
# 3997     400000
# Name: Salary, Length: 3998, dtype: int64>

# %% [markdown]
# ## cleaning designation coloumn

# %%
df['Designation'].value_counts()
# Out:
# software engineer                 539
# software developer                265
# system engineer                   205
# programmer analyst                139
# systems engineer                  118
#                                  ...
# business development managerde      1
# aircraft technician                 1
# electrical controls engineer        1
# sales trainer                       1
# software architect                  1
# Name: Designation, Length: 419, dtype: int64

# %%
df = df[~(df.Designation=='get')]

# %%
df[df.Designation=='associate software engineer']
# Out:
#            ID  Salary        DOJ                  DOL  \
# 38     550371  330000 2014-01-01              present
# 42     895673  350000 2014-08-01              present
# 190    864904  215000 2013-05-01  2014-04-01 00:00:00
# 249    746050  300000 2013-12-01              present
# 343    929120  300000 2014-02-01              present
# 385    984121  300000 2014-09-01  2015-03-01 00:00:00
# 439   1264748  205000 2014-08-01              present
# 632   1077591  240000 2013-10-01  2015-04-01 00:00:00
# 831   1094255  320000 2015-02-01  2015-05-01 00:00:00
# 885   1152411  315000 2015-03-01              present
# 1199   963241  380000 2014-07-01              present
# 1324   624224  300000 2014-09-01              present
# 1466  1247289  275000 2014-12-01              present
# 1608  1035879  385000 2014-09-01  2015-04-01 00:00:00
# 1778    34472  375000 2010-08-01  2011-11-01 00:00:00
# 1807  1043852  300000 2014-01-01  2015-04-01 00:00:00
# ...

# %%
df[df.Designation=='ase']
# Out:
#           ID  Salary        DOJ                  DOL Designation      JobCity  \
# 27    810458  300000 2014-09-01  2015-01-01 00:00:00         ase    Bangalore
# 2792  503183  360000 2013-07-01              present         ase         Pune
# 3839  644828  360000 2013-09-01              present         ase  bhubaneswar
#
#      Gender        DOB  10percentage      10board  ...  ComputerScience  \
# 27        m 1993-02-01         76.80  state board  ...               -1
# 2792      m 1991-08-10         86.33  state board  ...               -1
# 3839      f 1992-03-11         90.80  state board  ...               -1
#
#       MechanicalEngg ElectricalEngg  TelecomEngg  CivilEngg conscientiousness  \
# 27                -1             -1           -1         -1            0.9900
# 2792              -1             -1           -1         -1            0.2009
# 3839              -1            606           -1         -1            1.5644
#
# ...

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('ase','associate software engineer'))
# Out:
# <ipython-input-15-803572e90ec3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('ase','associate software engineer'))

# %%
df['Designation'].value_counts().nlargest(10)
# Out:
# software engineer             539
# software developer            265
# system engineer               205
# programmer analyst            139
# systems engineer              118
# java software engineer        111
# software test engineer        100
# project engineer               77
# technical support engineer     76
# senior software engineer       72
# Name: Designation, dtype: int64

# %%
df[df.Designation=='java software engineer']
# Out:
#            ID  Salary        DOJ                  DOL             Designation  \
# 6      947847  300000 2014-08-01  2015-05-01 00:00:00  java software engineer
# 14    1279958  300000 2013-07-01              present  java software engineer
# 29     472956  220000 2014-11-01  2014-04-01 00:00:00  java software engineer
# 64      31330  600000 2010-07-01  2012-07-01 00:00:00  java software engineer
# 71    1089599  250000 2014-05-01              present  java software engineer
# ...       ...     ...        ...                  ...                     ...
# 3872   938536  225000 2014-09-01  2015-02-01 00:00:00  java software engineer
# 3893  1269538  190000 2014-09-01  2015-05-01 00:00:00  java software engineer
# 3926   842595  300000 2014-05-01  2015-05-01 00:00:00  java software engineer
# 3955  1248250  185000 2014-10-01              present  java software engineer
# 3982   553436  160000 2012-05-01  2014-06-01 00:00:00  java software engineer
#
# ...

# %%
def Designation (x,y):
    for i in range(len(df['Designation'])):
        for k in x:
            if df['Designation'].iloc[i] == k:
                df['Designation'].iloc[i]=y
x=['java software engineer',]
y='software engineer'
Designation(x,y)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Roshith\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
import re

# %%
regex = "eer$"
df.Designation.apply(lambda x : re.findall(regex,x))
# Out:
# 0       [eer]
# 1          []
# 2       [eer]
# 3       [eer]
# 5       [eer]
#         ...
# 3993    [eer]
# 3994       []
# 3995    [eer]
# 3996       []
# 3997    [eer]
# Name: Designation, Length: 3984, dtype: object

# %% [markdown]
# ## Treating jobcity coloumn

# %%
df[df.JobCity==-1]
# Out:
#            ID  Salary        DOJ                  DOL  \
# 15     536517  350000 2013-08-01              present
# 21     339689  200000 2012-08-01  2013-12-01 00:00:00
# 39     533417  200000 2013-01-01  2013-06-01 00:00:00
# 77     754392  120000 2014-07-01              present
# 79    1089852  100000 2013-08-01  2014-05-01 00:00:00
# ...       ...     ...        ...                  ...
# 3937   385546  205000 2012-10-01  2014-02-01 00:00:00
# 3942  1067015  280000 2013-07-01              present
# 3954   531726  310000 2014-04-01  2015-04-01 00:00:00
# 3973   755067  335000 2013-08-01              present
# 3974   641821  180000 2013-06-01  2014-07-01 00:00:00
#
#                         Designation JobCity Gender        DOB  10percentage  \
# 15                 network engineer      -1      f 1990-01-17         69.54
# 21                software engineer      -1      f 1991-08-20         75.67
# 39               management trainee      -1      m 1991-02-28         88.00
# ...

# %%
gk = df.groupby(['JobCity'])['Designation'].count()

# %%
df[df['JobCity'] == -1]['Designation'].value_counts().nlargest(10)
# Out:
# software engineer             72
# software developer            34
# system engineer               18
# technical support engineer    13
# programmer analyst            12
# software test engineer        11
# systems engineer              10
# java developer                 9
# senior software engineer       9
# project engineer               7
# Name: Designation, dtype: int64

# %%
df[df['Designation'] =='software engineer']['JobCity'].value_counts().nlargest(10)
# Out:
# Bangalore      163
# -1              72
# Noida           71
# Hyderabad       57
# Pune            50
# Chennai         38
# Gurgaon         35
# Mumbai          27
# Navi Mumbai     15
# New Delhi       15
# Name: JobCity, dtype: int64

# %%
df['JobCity']=df['JobCity'].replace(to_replace=-1,value='Bangalore',regex=False)
# Out:
# <ipython-input-25-62ee6124eec8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace=-1,value='Bangalore',regex=False)

# %%
cr_1=pd.crosstab(df['Designation'],df['JobCity'])
cr_1
# Out:
# JobCity                         Chennai   Delhi   Mumbai   Pune   ariyalur  \
# Designation
# .net developer                        0       0        0      0          0
# .net web developer                    0       0        0      0          0
# account executive                     0       0        0      0          0
# account manager                       0       0        0      0          0
# admin assistant                       0       0        0      0          0
# ...                                 ...     ...      ...    ...        ...
# web designer and seo                  0       0        0      0          0
# web developer                         0       0        0      0          0
# web intern                            0       0        0      0          0
# website developer/tester              0       0        0      0          0
# windows systems administrator         0       0        0      0          0
#
# ...

# %%
df.drop([1439],axis=0,inplace=True)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.sort_values(by=['JobCity'])[3710:3780]
# Out:
#            ID  Salary        DOJ                  DOL  \
# 3124   538185  380000 2013-08-01              present
# 496    302687  445000 2011-09-01              present
# 659    641531  330000 2013-08-01              present
# 3261   538439  390000 2013-08-01              present
# 3812   883996  180000 2014-01-01              present
# ...       ...     ...        ...                  ...
# 2534   729532  200000 2013-04-01  2015-03-01 00:00:00
# 922     21229  500000 2010-02-01  2015-04-01 00:00:00
# 1082  1274066  180000 2014-08-01  2014-09-01 00:00:00
# 1949   991139  320000 2014-10-01              present
# 3165   765378  410000 2013-08-01              present
#
#                           Designation    JobCity Gender        DOB  \
# 3124        assistant system engineer      Thane      m 1991-08-17
# 496                 account executive      Thane      m 1989-07-28
# 659      product development engineer      Thane      m 1991-05-26
# ...

# %%
df['JobCity']=df['JobCity'].replace(to_replace='A-64,sec-64,noida',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Bhubaneshwar',value='BHUBANESWAR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Bhubaneswar',value='BHUBANESWAR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Bhubaneswar',value='BHUBANESWAR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Bhubneshwar',value='BHUBANESWAR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Chennai',value='CHENNAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Delhi',value='New Delhi',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Delhi/NCR',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Faridabad',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GREATER NOIDA',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Gajiabaad',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Ghaziabad',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Greater NOIDA',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Greater Noida',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Greater noida',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Gurgaon',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Gurgoan',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Gurgoan',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Gaziabaad',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Hyderabad',value='HYDERABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Indirapuram, Ghaziabad',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Indore',value='INDORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Noida',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Navi Mumbai',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='New Delhi',value='New Delhi',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Pune',value='PUNE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='SADULPUR,RAJGARH,DISTT-CHURU,RAJASTHAN',value='RAJASTHAN',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Sonipat',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='THANE',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Thane',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='bangalore',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='bengaluru',value='BANGALORE',regex=False)




df['JobCity']=df['JobCity'].replace(to_replace='Mumbai',value='MUMBAI',regex=False)


df['JobCity']=df['JobCity'].replace(to_replace='chennai',value='CHENNAI',regex=False)


df['JobCity']=df['JobCity'].replace(to_replace='pune',value='PUNE',regex=False)


df['JobCity']=df['JobCity'].replace(to_replace='hyderabad',value='HYDERABAD',regex=False)
# Out:
# <ipython-input-29-581a32ed0b9a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='A-64,sec-64,noida',value='NOIDA',regex=False)
# <ipython-input-29-581a32ed0b9a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='Bhubaneshwar',value='BHUBANESWAR',regex=False)
# <ipython-input-29-581a32ed0b9a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['JobCity']=df['JobCity'].replace(to_replace='Asifabadbanglore',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Bhopal',value='BHOPAL',regex=False)
# Out:
# <ipython-input-30-326cf2798037>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='Asifabadbanglore',value='BANGALORE',regex=False)
# <ipython-input-30-326cf2798037>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='Bhopal',value='BHOPAL',regex=False)

# %%
df['JobCity']=df['JobCity'].replace(to_replace='Bangalore',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='BAngalore',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Banagalore',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Banglore',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='BANGLORE',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Banaglore',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Bengaluru',value='BANGALORE',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Secunderabad',value='HYDERABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='banglore',value='BANGALORE',regex=False)
# Out:
# <ipython-input-31-f31de40275c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='Bangalore',value='BANGALORE',regex=False)
# <ipython-input-31-f31de40275c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='BAngalore',value='BANGALORE',regex=False)
# <ipython-input-31-f31de40275c8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['JobCity']=df['JobCity'].replace(to_replace='Ambala City',value='Ambala',regex=False)
# Out:
# <ipython-input-32-d2eea7cadef3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='Ambala City',value='Ambala',regex=False)

# %%
df['JobCity']
# Out:
# 0        BANGALORE
# 1           INDORE
# 2          CHENNAI
# 3              NCR
# 5        HYDERABAD
#            ...
# 3993    New Delhi
# 3994     HYDERABAD
# 3995     BANGALORE
# 3996     BANGALORE
# 3997       CHENNAI
# Name: JobCity, Length: 3983, dtype: object

# %%
df[df.JobCity=='Bangalore']
# Out:
# Empty DataFrame
# Columns: [ID, Salary, DOJ, DOL, Designation, JobCity, Gender, DOB, 10percentage, 10board, 12graduation, 12percentage, 12board, CollegeID, CollegeTier, Degree, Specialization, collegeGPA, CollegeCityID, CollegeCityTier, CollegeState, GraduationYear, English, Logical, Quant, Domain, ComputerProgramming, ElectronicsAndSemicon, ComputerScience, MechanicalEngg, ElectricalEngg, TelecomEngg, CivilEngg, conscientiousness, agreeableness, extraversion, nueroticism, openess_to_experience]
# Index: []
#
# [0 rows x 38 columns]

# %%
df
# Out:
#            ID   Salary        DOJ                  DOL  \
# 0      203097   420000 2012-06-01              present
# 1      579905   500000 2013-09-01              present
# 2      810601   325000 2014-06-01              present
# 3      267447  1100000 2011-07-01              present
# 5     1027655   300000 2014-06-01              present
# ...       ...      ...        ...                  ...
# 3993    47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994   752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995   355888   320000 2013-07-01              present
# 3996   947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997   324966   400000 2013-02-01              present
#
#                       Designation     JobCity Gender        DOB  10percentage  \
# 0         senior quality engineer   BANGALORE      f 1990-02-19         84.30
# 1               assistant manager      INDORE      m 1989-10-04         85.40
# ...

# %%
df.drop([2488],axis=0,inplace=True)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df['JobCity'] = df['JobCity'].apply(lambda x:x.replace('thane','MUMBAI').replace('Thiruvananthapuram','TRIVANDRUM').replace('sonepat','NCR'))
# Out:
# <ipython-input-37-422a38c421d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity'] = df['JobCity'].apply(lambda x:x.replace('thane','MUMBAI').replace('Thiruvananthapuram','TRIVANDRUM').replace('sonepat','NCR'))

# %%
df['JobCity'] = df['JobCity'].apply(lambda x:x.strip())
# Out:
# <ipython-input-38-54eb952dfc96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity'] = df['JobCity'].apply(lambda x:x.strip())

# %%
df['JobCity'].value_counts().nlargest(200)
# Out:
# BANGALORE    1129
# NOIDA         404
# HYDERABAD     357
# PUNE          320
# CHENNAI       304
#              ...
# Roorkee         1
# NEW DELHI       1
# Guwahati        1
# Jhansi          1
# Patiala         1
# Name: JobCity, Length: 200, dtype: int64

# %%
df.drop(df['JobCity'].value_counts().nlargest(200)[100:150],axis=0,inplace=True)

# %%
#df[df.JobCity=='Bhopal']RAE BARELI

# %%
df['JobCity']=df['JobCity'].replace(to_replace='kolkata',value='Kolkata',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Kolkata',value='Kolkata',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='noida',value='NOIDA',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Trivandrum',value='TRIVANDRUM',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='DELHI',value='New Delhi',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='DELHI',value='New Delhi',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='KOLKATA',value='Kolkata',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='new delhi',value='New Delhi',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='new delhi',value='New Delhi',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='NEW DELHI',value='New Delhi',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='mumbai',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Navi Mumbai , Hyderabad',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='gurgaon',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GURAGAON',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Kochi/Cochin',value='Kochi',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='hderabad',value='HYDERABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='GURGAON',value='NCR',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Kochi/Cochin, Chennai and Coimbatore',value='CHENNAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Chennai, Bangalore ',value='CHENNAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Chennai & Mumbai',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Chennai, Bangalore',value='CHENNAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='hyderabad(bhadurpally)',value='HYDERABAD',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Technopark, Trivandrum',value='TRIVANDRUM',regex=False)               
df['JobCity']=df['JobCity'].replace(to_replace='ghaziabad',value='NCR',regex=False)   
df['JobCity']=df['JobCity'].replace(to_replace='NAVI MUMBAI',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='Navi mumbai',value='MUMBAI',regex=False)
df['JobCity']=df['JobCity'].replace(to_replace='trivandrum',value='TRIVANDRUM',regex=False)
# Out:
# <ipython-input-42-aa0a4bb65453>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='kolkata',value='Kolkata',regex=False)
# <ipython-input-42-aa0a4bb65453>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity']=df['JobCity'].replace(to_replace='Kolkata',value='Kolkata',regex=False)
# <ipython-input-42-aa0a4bb65453>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df[df.JobCity=='visakapatanam']

df['JobCity'] = df['JobCity'].apply(lambda x:x.replace('Vizag','visakapatanam').replace('vsakhapttnam','visakapatanam').replace('vizag','visakapatanam'))
# Out:
# <ipython-input-43-0bb54da05349>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['JobCity'] = df['JobCity'].apply(lambda x:x.replace('Vizag','visakapatanam').replace('vsakhapttnam','visakapatanam').replace('vizag','visakapatanam'))

# %%
df[df.JobCity=='vsakhapttnam']
# Out:
# Empty DataFrame
# Columns: [ID, Salary, DOJ, DOL, Designation, JobCity, Gender, DOB, 10percentage, 10board, 12graduation, 12percentage, 12board, CollegeID, CollegeTier, Degree, Specialization, collegeGPA, CollegeCityID, CollegeCityTier, CollegeState, GraduationYear, English, Logical, Quant, Domain, ComputerProgramming, ElectronicsAndSemicon, ComputerScience, MechanicalEngg, ElectricalEngg, TelecomEngg, CivilEngg, conscientiousness, agreeableness, extraversion, nueroticism, openess_to_experience]
# Index: []
#
# [0 rows x 38 columns]

# %%
def city(x,y):
    for i in range(len(df['JobCity'])):
        for k in x:
            if df['JobCity'].iloc[i] == k:
                df['JobCity'].iloc[i]=y
x=['delhi']
y='New Delhi'
city(x,y)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\Roshith\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
df['JobCity'].value_counts().nlargest(10)
# Out:
# BANGALORE    1129
# NOIDA         417
# HYDERABAD     359
# PUNE          320
# CHENNAI       306
# NCR           253
# New Delhi     223
# MUMBAI        158
# Kolkata       119
# Jaipur         47
# Name: JobCity, dtype: int64

# %% [markdown]
# ## cleaning gender coloumn

# %%
df['Gender'].value_counts()
# Out:
# m    3024
# f     957
# Name: Gender, dtype: int64

# %%
#df.to_csv('Downloads/aspiring_minds_employability_outcomes_2015.csv')

# %%
df['10board'].value_counts()
# Out:
# cbse                                     1385
# state board                              1163
# 0                                         349
# icse                                      280
# ssc                                       120
#                                          ...
# national public school                      1
# maharashtra state board pune                1
# dav public school sec 14                    1
# latur board                                 1
# board of school education uttarakhand       1
# Name: 10board, Length: 274, dtype: int64

# %%
#df['10board']=df['10board'].apply(lambda x:'state board'if x=='maharashtra sate board' or x=='punjab school education board, mohali'or x=='mp state board'or x=='board of secendary education orissa'or x=='maharashtra nasik board'or x=='msbshse,pune'or x=='ksseb(karnataka state board)'or x=='ssc maharashtra board'or x=='bright way college, (up board)' or x=='board of secondary education (bse) orissa' or x=='up baord'or x=='bse(board of secondary education)'or x=='maharashtra state board,pune'or x=='hse,board'or x=='metric'or x=='school secondary education, andhra pradesh'or x=='maharastra board'or x=='mhsbse'or x='karnataka secondory education board' else x)

# %%
df.rename(columns={'10board':'Xboard'},inplace = True)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df['Xboard'].value_counts()
# Out:
# cbse                                     1385
# state board                              1163
# 0                                         349
# icse                                      280
# ssc                                       120
#                                          ...
# national public school                      1
# maharashtra state board pune                1
# dav public school sec 14                    1
# latur board                                 1
# board of school education uttarakhand       1
# Name: Xboard, Length: 274, dtype: int64

# %%
df[df.Xboard== 0]
# Out:
#           ID  Salary        DOJ                  DOL              Designation  \
# 44    247617  380000 2012-05-01  2015-04-01 00:00:00       programmer analyst
# 57    294700  525000 2012-03-01              present            test engineer
# 84     58674  445000 2011-11-01              present   software test engineer
# 101    43693  205000 2011-12-01              present      electrical engineer
# 114    50876  640000 2010-04-01              present       programmer analyst
# ...      ...     ...        ...                  ...                      ...
# 3961  230702  700000 2011-07-01  2014-09-01 00:00:00        planning engineer
# 3977  217036  415000 2011-09-01              present        software engineer
# 3988  466661  200000 2013-02-01  2013-07-01 00:00:00             data analyst
# 3990  204287  480000 2012-02-01              present  senior systems engineer
# 3992  344407  800000 2014-04-01  2015-04-01 00:00:00                  manager
#
# ...

# %%
#df['Xboard'].apply(lambda x:df.dropna('Xboard'.axis=0) if df[df.Xboard== 0] else x)

# %% [markdown]
# ## treating salary col

# %%
df['Salary'].value_counts()
# Out:
# 300000     293
# 180000     237
# 200000     203
# 325000     188
# 120000     165
#           ...
# 785000       1
# 900000       1
# 810000       1
# 2600000      1
# 1110000      1
# Name: Salary, Length: 176, dtype: int64

# %%
df[df.Specialization=='internal combustion engine']
# Out:
#            ID  Salary        DOJ                  DOL    Designation  JobCity  \
# 2435  1067508  360000 2015-02-01  2015-04-01 00:00:00  test engineer  Chennai
#
#      Gender        DOB  10percentage Xboard  ...  ComputerScience  \
# 2435      m 1990-09-04          76.0   cbse  ...               -1
#
#       MechanicalEngg ElectricalEngg  TelecomEngg  CivilEngg conscientiousness  \
# 2435             438             -1           -1         -1            0.4155
#
#      agreeableness  extraversion  nueroticism  openess_to_experience
# 2435        0.0459       -0.4511      -0.3612                -0.8608
#
# [1 rows x 38 columns]

# %%
df.Specialization.value_counts()
# Out:
# electronics and communication engineering      878
# computer science & engineering                 744
# information technology                         660
# computer engineering                           600
# computer application                           244
# electronics and electrical engineering         193
# mechanical engineering                         193
# electronics & telecommunications               121
# electrical engineering                          81
# electronics & instrumentation eng               32
# civil engineering                               29
# electronics and instrumentation engineering     27
# information science engineering                 27
# instrumentation and control engineering         20
# electronics engineering                         18
# biotechnology                                   14
# other                                           13
# industrial & production engineering             10
# ...

# %%
 df['Specialization']=df['Specialization'].apply(lambda x:x.replace('information science engineering','Information Technology').replace('Information Technology','information technology'))
# Out:
# <ipython-input-58-4b2fa8ed90dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Specialization']=df['Specialization'].apply(lambda x:x.replace('information science engineering','Information Technology').replace('Information Technology','information technology'))

# %%
df['Specialization']=df['Specialization'].apply(lambda x:x.replace('internal combustion engine','automobile/automotive engineering'))
# Out:
# <ipython-input-59-ed19c31723d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Specialization']=df['Specialization'].apply(lambda x:x.replace('internal combustion engine','automobile/automotive engineering'))

# %%
 df['Specialization']=df['Specialization'].apply(lambda x:x.replace('computer engineering','computer engineering').replace('computer science & engineering','computer engineering').replace('computer science','computer engineering').replace('computer engineering and technology','computer engineering'))
# Out:
# <ipython-input-60-eb0f98e717c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Specialization']=df['Specialization'].apply(lambda x:x.replace('computer engineering','computer engineering').replace('computer science & engineering','computer engineering').replace('computer science','computer engineering').replace('computer engineering and technology','computer engineering'))

# %%
df['Specialization']=df['Specialization'].apply(lambda x:x.strip())
# Out:
# <ipython-input-61-0d0049702674>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Specialization']=df['Specialization'].apply(lambda x:x.strip())

# %%
#df.to_csv('Downloads/aspiring_minds_employability_outcomes_2015.csv')

# %% [markdown]
# ## Cleaning Designation

# %%
df['Designation']=df['Designation'].replace(to_replace='assistant systems engineer',value='assistant system engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='telecom engineer',value='telecommunication engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='systems administrator',value='system administrator',regex=False)
df['Designation']=df['Designation'].replace(to_replace='systems analyst',value='system analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='systems engineer',value='system engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software test engineer (etl)',value='software test engineerte',regex=False)
df['Designation']=df['Designation'].replace(to_replace='r & d',value='r&d engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='qa engineer',value='quality engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='qa analyst',value='quality analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='operations executive',value='operation executive',regex=False)
df['Designation']=df['Designation'].replace(to_replace='operations engineer',value='operation engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='jr. software developer',value='junior software developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='jr. software engineer',value='junior software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='front end web developer',value='front end developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='executive engg',value='executive engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='.net developer',value='dotnet developer',regex=False)

df['Designation']=df['Designation'].replace(to_replace='associate software engg',value='associate software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='assistant system engineer trainee',value='assistant system engineer - trainee',regex=False)
# Out:
# <ipython-input-63-cddb7911eacc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].replace(to_replace='assistant systems engineer',value='assistant system engineer',regex=False)
# <ipython-input-63-cddb7911eacc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].replace(to_replace='telecom engineer',value='telecommunication engineer',regex=False)
# <ipython-input-63-cddb7911eacc>:3: SettingWithCopyWarning:
# ...

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('get','Graduate Engineer Trainee').replace('graduate trainee engineer','Graduate Engineer Trainee'))
# Out:
# <ipython-input-64-8982d014bdd5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('get','Graduate Engineer Trainee').replace('graduate trainee engineer','Graduate Engineer Trainee'))

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('programmer analyst','Programming Analyst'))
# Out:
# <ipython-input-65-c472570c5998>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('programmer analyst','Programming Analyst'))

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('software enginner','software engineer').replace('software engineere','software engineer').replace('software eng','software engineer').replace('software engg','software engineer'))
# Out:
# <ipython-input-66-a143eeda4906>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('software enginner','software engineer').replace('software engineere','software engineer').replace('software eng','software engineer').replace('software engg','software engineer'))

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('software engineerineer','software engineer').replace('software engineerineer','senior software engineer').replace('technical support engineesenior','software engineer'))
# Out:
# <ipython-input-67-64131ddfa190>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('software engineerineer','software engineer').replace('software engineerineer','senior software engineer').replace('technical support engineesenior','software engineer'))

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('software engineer','Software Engineer'))
# Out:
# <ipython-input-68-e98a35916f3e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('software engineer','Software Engineer'))

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('hardware engineer','Hardware Engineer'))
# Out:
# <ipython-input-69-b1e8922f420f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('hardware engineer','Hardware Engineer'))

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('associate engineer','Associate Engineer'))
# Out:
# <ipython-input-70-182176a588bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('associate engineer','Associate Engineer'))

# %%
df[df.Designation=='Associate Engineer']
# Out:
#            ID  Salary        DOJ                  DOL         Designation  \
# 209    602058  300000 2014-06-01  2015-04-01 00:00:00  Associate Engineer
# 518    625251  515000 2013-09-01              present  Associate Engineer
# 819   1068402  350000 2014-04-01              present  Associate Engineer
# 2563  1085682   80000 2013-02-01  2015-03-01 00:00:00  Associate Engineer
# 3134   831825  315000 2015-03-01              present  Associate Engineer
# 3771   655292  180000 2014-09-01              present  Associate Engineer
#
#         JobCity Gender        DOB  10percentage       Xboard  ...  \
# 209   BANGALORE      f 1992-01-04         87.00  state board  ...
# 518   HYDERABAD      m 1992-02-26         84.80         cbse  ...
# 819   BANGALORE      m 1993-06-16         74.83  state board  ...
# 2563        NCR      m 1990-10-28         51.60     up board  ...
# 3134    CHENNAI      m 1992-09-02         73.40  state board  ...
# ...

# %%
df['Designation']=df['Designation'].replace(to_replace='dotnet developer',value='.net developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='.net web developer',value='.net developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='assistant system engineer - trainee',value='assistant system engineer trainee',regex=False)
df['Designation']=df['Designation'].replace(to_replace='assistant systems engineer',value='assistant system engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='associate software engg',value='associate software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='business development managerde',value='business development manager',regex=False)
df['Designation']=df['Designation'].replace(to_replace='business systems analyst',value='business system analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='co faculty',value='computer faculty',regex=False)
df['Designation']=df['Designation'].replace(to_replace='db2 dba',value='databapplication support engineer administrator',regex=False)
df['Designation']=df['Designation'].replace(to_replace='dba',value='databapplication support engineer administrator',regex=False)
df['Designation']=df['Designation'].replace(to_replace='executive engg',value='executive engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='front end web developer',value='front end developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='graduate trainee engineer',value='graduate engineer trainee',regex=False)
df['Designation']=df['Designation'].replace(to_replace='hr executive',value='executive hr',regex=False)
df['Designation']=df['Designation'].replace(to_replace='jr. software engineer',value='junior software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='operations engineer and jetty handling',value='operations engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='qa analyst',value='quality analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='qa engineer',value='quality engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='qa trainee',value='quality trainee',regex=False)
df['Designation']=df['Designation'].replace(to_replace='r & d',value='r&d engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='rf/dt engineer',value='rf engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='sales and service engineer',value='sales & service engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='seo',value='seo analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software devloper',value='software developer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software eng',value='software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software engg',value='software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software engineere',value='software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software enginner',value='software engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software test engineer (etl)',value='software test engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='software test engineerte',value='software test engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='sr. engineer',value='senior engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='team leader',value='team lead',regex=False)
df['Designation']=df['Designation'].replace(to_replace='systems analyst',value='system analyst',regex=False)
df['Designation']=df['Designation'].replace(to_replace='systems administrator',value='system administrator',regex=False)
df['Designation']=df['Designation'].replace(to_replace='testing engineer',value='test engineer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='web designer and joomla administrator',value='web designer',regex=False)
df['Designation']=df['Designation'].replace(to_replace='web designer and seo',value='web designer',regex=False)
# Out:
# <ipython-input-72-d1f74222fc77>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].replace(to_replace='dotnet developer',value='.net developer',regex=False)
# <ipython-input-72-d1f74222fc77>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].replace(to_replace='.net web developer',value='.net developer',regex=False)
# <ipython-input-72-d1f74222fc77>:3: SettingWithCopyWarning:
# ...

# %%
len(df['Designation'].value_counts())
# Out:
# 379

# %%
df['Designation']=df['Designation'].apply(lambda x:x.replace('programmer analyst','Programming Analyst'))
df['Designation']=df['Designation'].apply(lambda x:x.replace('hardware engineer','Hardware Engineer'))
df['Designation']=df['Designation'].apply(lambda x:x.replace('associate engineer','Associate Engineer'))
df['Designation']=df['Designation'].apply(lambda x:x.replace('software engineer','Software Engineer'))
# Out:
# <ipython-input-74-38ee2df98df2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('programmer analyst','Programming Analyst'))
# <ipython-input-74-38ee2df98df2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Designation']=df['Designation'].apply(lambda x:x.replace('hardware engineer','Hardware Engineer'))
# <ipython-input-74-38ee2df98df2>:3: SettingWithCopyWarning:
# ...

# %% [markdown]
# ## Treating Salary

# %%
df['Salary']=df['Salary'].astype(int)
df['Salary']
# Out:
# <ipython-input-75-551b8c8c818a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary']=df['Salary'].astype(int)
# 0        420000
# 2        325000
# 3       1100000
# 5        300000
# 6        300000
#          ...
# 3993     280000
# 3994     100000
# 3995     320000
# 3996     200000
# 3997     400000
# Name: Salary, Length: 3981, dtype: int32

# %%
df
# Out:
#            ID   Salary        DOJ                  DOL  \
# 0      203097   420000 2012-06-01              present
# 2      810601   325000 2014-06-01              present
# 3      267447  1100000 2011-07-01              present
# 5     1027655   300000 2014-06-01              present
# 6      947847   300000 2014-08-01  2015-05-01 00:00:00
# ...       ...      ...        ...                  ...
# 3993    47916   280000 2011-10-01  2012-10-01 00:00:00
# 3994   752781   100000 2013-07-01  2013-07-01 00:00:00
# 3995   355888   320000 2013-07-01              present
# 3996   947111   200000 2014-07-01  2015-01-01 00:00:00
# 3997   324966   400000 2013-02-01              present
#
#                       Designation    JobCity Gender        DOB  10percentage  \
# 0         senior quality engineer  BANGALORE      f 1990-02-19         84.30
# 2                 system engineer    CHENNAI      f 1992-08-03         85.00
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', 'Xboard', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %% [markdown]
# ## Cleaning GraduationYear

# %%
df['GraduationYear'].value_counts()
# Out:
# 2013    1179
# 2014    1031
# 2012     843
# 2011     505
# 2010     289
# 2015      93
# 2009      24
# 2017       8
# 2016       7
# 0          1
# 2007       1
# Name: GraduationYear, dtype: int64

# %%
df.drop([2664],axis=0,inplace=True)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ## Cleaning Degree

# %%
df.Degree.value_counts()
# Out:
# B.Tech/B.E.      3683
# MCA               243
# M.Tech./M.E.       52
# M.Sc. (Tech.)       2
# Name: Degree, dtype: int64

# %%
df['collegeGPA'].value_counts()
# Out:
# 70.00    112
# 72.00     99
# 75.00     83
# 65.00     79
# 71.00     74
#         ...
# 61.30      1
# 60.19      1
# 57.25      1
# 61.44      1
# 61.47      1
# Name: collegeGPA, Length: 1278, dtype: int64

# %% [markdown]
# ## Cleaning CollegeState

# %%
df['CollegeState'].value_counts()
# Out:
# Uttar Pradesh        911
# Karnataka            370
# Tamil Nadu           367
# Telangana            317
# Maharashtra          261
# Andhra Pradesh       224
# West Bengal          196
# Punjab               191
# Madhya Pradesh       187
# Haryana              179
# Rajasthan            174
# Orissa               172
# Delhi                160
# Uttarakhand          113
# Kerala                33
# Jharkhand             26
# Chhattisgarh          26
# Gujarat               24
# Himachal Pradesh      16
# Bihar                 10
# Jammu and Kashmir      7
# Assam                  5
# Union Territory        5
# Sikkim                 3
# Meghalaya              2
# Goa                    1
# Name: CollegeState, dtype: int64

# %%
df[df.GraduationYear==0]
# Out:
# Empty DataFrame
# Columns: [ID, Salary, DOJ, DOL, Designation, JobCity, Gender, DOB, 10percentage, Xboard, 12graduation, 12percentage, 12board, CollegeID, CollegeTier, Degree, Specialization, collegeGPA, CollegeCityID, CollegeCityTier, CollegeState, GraduationYear, English, Logical, Quant, Domain, ComputerProgramming, ElectronicsAndSemicon, ComputerScience, MechanicalEngg, ElectricalEngg, TelecomEngg, CivilEngg, conscientiousness, agreeableness, extraversion, nueroticism, openess_to_experience]
# Index: []
#
# [0 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', 'Xboard', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
len(df['Specialization'].unique())
# Out:
# 41

# %%
len(df['JobCity'].value_counts())
# Out:
# 237

# %%
len(df['JobCity'].unique())
# Out:
# 237

# %% [markdown]
# ## Cleaning ComputerScience col

# %%
df[df.ComputerScience==-1].head()
# Out:
#        ID   Salary        DOJ                  DOL               Designation  \
# 0  203097   420000 2012-06-01              present   senior quality engineer
# 2  810601   325000 2014-06-01              present           system engineer
# 3  267447  1100000 2011-07-01              present  senior Software Engineer
# 7  912934   400000 2014-07-01  2015-07-01 00:00:00       mechanical engineer
# 8  552574   600000 2013-07-01              present       electrical engineer
#
#      JobCity Gender        DOB  10percentage                          Xboard  \
# 0  BANGALORE      f 1990-02-19          84.3  board ofsecondary education,ap
# 2    CHENNAI      f 1992-08-03          85.0                            cbse
# 3        NCR      m 1989-12-05          85.6                            cbse
# 7  BANGALORE      m 1992-05-27          92.0                            cbse
# 8      NOIDA      m 1991-09-17          90.0                            cbse
#
# ...

# %%
df['ComputerScience']=df['ComputerScience'].apply(lambda x:str(x.replace(-1,'')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-123-b0520f1ed05b> in <module>
# ----> 1 df['ComputerScience']=df['ComputerScience'].apply(lambda x:str(x.replace(-1,'')))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-123-b0520f1ed05b> in <lambda>(x)
# ----> 1 df['ComputerScience']=df['ComputerScience'].apply(lambda x:str(x.replace(-1,'')))
#
# AttributeError: 'int' object has no attribute 'replace'

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ## Salary

# %%
plt.figure(figsize=(15, 7))
sns.distplot(df['Salary'],hist=True)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary', ylabel='Density'>

# %%
sns.boxplot(data=df['Salary'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# OBSERVATION: We can see that the median salary for majority people is 30,000 INR per mounth, and also there are people with more than 100000 INR per mounth.

# %%
plt.figure(figsize=(15, 7))
sns.distplot(df['10percentage'],hist=False,rug=True)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='10percentage', ylabel='Density'>

# %% [markdown]
# OBSERVATION:We can see that the data is left skewed, there is high density of people with percentage rage between 70 to 90%, there some exceptions towards the leftside ie; below 50%.
# Overall we can say that the majority of the candidates have 1st class division in their 10th grade.

# %%
sns.boxplot(data=df['10percentage'])
sns.set_style('whitegrid')

# %% [markdown]
# OBSERVATION: We can see that the 25percentage of candiates have above 70% median percentage or 50percent of the candidates is close to 80%, and 75percent of candidates have above 80%.which is very good,although there some exceptions ie; below 50%.
# Overall we can say that the majority of the candidates have 1st class division in their 10th grade.

# %%
plt.figure(figsize=(15, 7))
sns.distplot(df['12percentage'],hist=False,rug=True)
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='12percentage', ylabel='Density'>

# %% [markdown]
# OBSERVATION:We can see that the distribution is slightly left skewed, majority of the candidates have the 12thpercentage in the range of 60% to 85% and then the density gets less for percentages above 85, and there are very less candidates who have their 12percentage less than 50%.

# %%
sns.boxplot(data=df['12percentage'])
sns.set_style('whitegrid')

# %% [markdown]
# OBSERVATION: The 25% percent of people have their 12thpercentage close to 70%, 50% percent of people have their percentage 75% and 75 percent candidates have their 12th percentage a little over 80% and some exceptions candidates with percentage below 45%.(Outliers)

# %% [markdown]
# ## GraduationYear

# %%
plt.figure(figsize=(15, 7))
sns.distplot(df['GraduationYear'],hist=False,rug=True)
sns.set_style('whitegrid')
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# OBSERVATION:We can see that there are 5 peaks in the distribution at 2010,2011,2012,2013,2014,
# We can also infer that there was highest number of candidates who graduated in the year 2013, who have appeared for the amcat exam.

# %%
plt.figure(figsize=(15, 7))
sns.distplot(df['JobCity'].value_counts().nlargest(10))
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='JobCity', ylabel='Density'>

# %%
OBSERVATION:We can see that the top 10 jobcities

# %%
plt.figure(figsize=(15, 7))
sns.countplot(df['Gender'])
sns.set_style('whitegrid')
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# OBSERVATION: We can the comparision between the male and female candidates, which clearly shows that the differnce between the number of male candidates and female candidates is three times more.

# %%
df['Salary'].min()
# Out:
# 35000

# %%
plt.figure(figsize=(5,10))
explode = [0,3,0.2]
plt.pie(df['Gender'].value_counts(),startangle=90,autopct="%3f",
        labels=['m','f'],shadow=True,explode=explode)
plt.title('Distribution of houses in the given range',fontsize=25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-b3b603c435f5> in <module>
#       1 plt.figure(figsize=(5,10))
#       2 explode = [0,3,0.2]
# ----> 3 plt.pie(df['Gender'].value_counts(),startangle=90,autopct="%3f",
#       4         labels=['m','f'],shadow=True,explode=explode)
#       5 plt.title('Distribution of houses in the given range',fontsize=25)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
# ...

# %%
df[df.Gender=='f']

# %%
plt.figure(figsize=(15, 7))
df.groupby(['Gender'])['Salary'].plot(kind = 'kde')
sns.set_style('whitegrid')

# %%
sns.kdeplot(male['Salary'],
            male['Salary'],
            color='r', shade=True, Label='male',
            cmap="Reds", shade_lowest=False)
  
sns.kdeplot(female['Salary'], 
            female['Salary'], color='b',
            shade=True, Label='female',
            cmap="Blues", shade_lowest=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15, 7))
df.groupby(['Gender'])['Salary'].min().plot(kind = 'bar')
sns.set_style('whitegrid')

# %% [markdown]
# OBSERVATION: We can see that the minimum salary or sarting salary for both male and female in our data is 35000 INR, and we also observe that there no bias towards any gender.

# %%
plt.figure(figsize=(15, 7))
df.groupby(['Gender'])['Salary'].max().plot(kind = 'bar')
sns.set_style('whitegrid')

# %% [markdown]
# OBSERVATION: We can see that the

# %%
df['Salary'].max()
# Out:
# 4000000

# %%
# Out:
# 0        -1
# 2        -1
# 3        -1
# 5       407
# 6       346
#        ...
# 3993     -1
# 3994     -1
# 3995     -1
# 3996    438
# 3997     -1
# Name: ComputerScience, Length: 3980, dtype: int64

# %%
plt.figure(figsize=(15, 7))
df.groupby(['ComputerScience'])['Salary'].min().plot(kind = 'bar')
sns.set_style('whitegrid')

# %%
plt.figure(figsize=(15, 7))
df.groupby(['MechanicalEngg'])['Salary'].min().plot(kind = 'kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
plt.figure(figsize=(15, 7))
df.groupby(['ElectricalEngg'])['Salary'].min().plot(kind = 'kde')

# %%
plt.figure(figsize=(15, 7))
df.groupby(['CivilEngg'])['Salary'].min().plot(kind = 'kde')

# %%
sns.jointplot(x='', y='',\
              data=Data, kind='hex')

# %%
df.columns
# Out:
# Index(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', 'Xboard', '12graduation', '12percentage', '12board',
#        'CollegeID', 'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityID', 'CollegeCityTier', 'CollegeState', 'GraduationYear',
#        'English', 'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
sns.relplot(x ='collegeGPA', y ="Salary", 
            hue ="CollegeTier", data = df);

# %% [markdown]
# OBSERVATION:We can see that salary difference between a tier1 and tier2 college might be little in the begining of the career but in the later stages it is not huge, even if a person is graduated from a tier 2 college he/she can be payed as high as a person from tier1 college.

# %%
plt.figure(figsize=(15, 10))
sns.distplot(df['openess_to_experience'])

# %%
plt.figure(figsize=(15, 10))
sns.distplot(df[''])

# %%
plt.figure(figsize=(15, 7))
sns.countplot(df['CollegeTier'])
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CollegeTier', ylabel='count'>

# %% [markdown]
# OBSERVATION:We can see that the number of tier2 colleges are more than 14times the number of tier1 college.

# %%
plt.figure(figsize=(15, 7))
sns.countplot(df['GraduationYear'])
# Out:
# C:\Users\Roshith\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GraduationYear', ylabel='count'>

# %% [markdown]
# OBSERVATION: We can see there was gradual increase in the count of candidates who appeared for the exam from the year 2010 to 2013 then it starts reducing we see a sharp fall in 2015.

# %%
# Out:
# <AxesSubplot:xlabel='Specialization', ylabel='Salary'>

# %%
df[df.Designation=='programming analyst']

# %%
df['Designation'].value_counts()
